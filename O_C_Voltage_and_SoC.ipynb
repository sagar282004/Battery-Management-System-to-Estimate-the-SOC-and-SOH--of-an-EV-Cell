# %% [markdown]
# <a href="https://colab.research.google.com/github/sagar282004/Battery-Management-System-to-Estimate-the-SOC-and-SOH--of-an-EV-Cell/blob/main/O_C_Voltage_and_SoC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

ocv_soc_df = pd.read_csv("OCV_vs_SOC_curve.csv")

# Preview
print(ocv_soc_df.head())

# Plot OCV vs SOC curve
plt.figure(figsize=(8,6))
plt.plot(ocv_soc_df['SOC'], ocv_soc_df['V0'])
plt.xlabel('State of Charge (SoC)')
plt.ylabel('Open Circuit Voltage (V)')
plt.title('OCV vs SoC Curve')
plt.grid(True)
plt.show()
# Out:
#      SOC        V0
# 0  0.000  3.010470
# 1  0.001  3.031911
# 2  0.002  3.049571
# 3  0.003  3.065900
# 4  0.004  3.080937
